# %%
import pandas as pd
import numpy as np

# %%
#reading data
data=pd.read_csv("SuperStoreOrders.csv")

# %%
#get top rows
data.head(5)
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
#checking datatypes of a dataframe
data.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
#checking data of particular column
data['year'].dtype
# Out:
# dtype('int64')

# %%
#selecting a particular column
data['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 51285    2014
# 51286    2014
# 51287    2014
# 51288    2014
# 51289    2014
# Name: year, Length: 51290, dtype: int64

# %%
#grouping a data
data1=data.groupby('category')
data1.mean()
# Out:
# C:\Users\SingareddyNagaTriven\AppData\Local\Temp\ipykernel_1100\4286887909.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.mean()
#                  quantity  discount     profit  shipping_cost         year
# category
# Furniture        3.539287  0.168087  29.038300      44.584919  2012.775010
# Office Supplies  3.459278  0.137409  16.578961      12.964899  2012.780322
# Technology       3.468691  0.135342  65.454958      49.999876  2012.769747

# %%
#filtering of data
data_filter = data[ data['year'] >2013]
data_filter
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  3/1/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  5/1/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  3/1/2014    Second Class
# 33762   US-2014-105830    1/1/2014  3/1/2014     First Class
# 33763   CA-2014-160395    1/1/2014  7/1/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
#to fill null value we can use fillna
#to drop null values use dropna
#to drop columns use drop function

# %%
# finding and filling missing values
missed_data=pd.DataFrame({'a':[1,2,np.nan,4],'b':[np.nan,5,6,7]})

# %%
missed_data
# Out:
#      a    b
# 0  1.0  NaN
# 1  2.0  5.0
# 2  NaN  6.0
# 3  4.0  7.0

# %%
# while apply any mathematical operations like sum the column will consider missing values as zero
missed_data['a'].sum()
# Out:
# 0    1.0
# 1    3.0
# 2    3.0
# 3    7.0
# Name: a, dtype: float64

# %%
#handling null values
missed_data.isnull().sum()
# Out:
# a    1
# b    1
# dtype: int64

# %%
#filling missing values
missed_data['a'].fillna(0,inplace=True)

# %%
missed_data
# Out:
#      a    b
# 0  1.0  NaN
# 1  2.0  5.0
# 2  0.0  6.0
# 3  4.0  7.0

# %%
#aggerating data
data[['quantity','profit','year']].agg(['min','max'])
# Out:
#      quantity    profit  year
# min         1 -6599.978  2011
# max        14  8399.976  2014

# %%
#soring data
missed_data_sorted = missed_data.sort_values(by=['a'],ascending=False)

# %%
missed_data_sorted
# Out:
#      a    b
# 3  4.0  7.0
# 1  2.0  5.0
# 0  1.0  NaN
# 2  0.0  6.0
